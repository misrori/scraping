# %%
# !pip install scrapethat
# Out:
# Collecting scrapethat
#   Downloading scrapethat-1.0.3-py3-none-any.whl (2.1 kB)
# Collecting bs4 (from scrapethat)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from scrapethat) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from scrapethat) (1.5.3)
# Collecting cloudscraper (from scrapethat)
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->scrapethat) (4.11.2)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.10/dist-packages (from cloudscraper->scrapethat) (3.1.1)
# Collecting requests-toolbelt>=0.9.1 (from cloudscraper->scrapethat)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->scrapethat) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->scrapethat) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->scrapethat) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->scrapethat) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scrapethat) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scrapethat) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->scrapethat) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->scrapethat) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->scrapethat) (2.5)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=e19c9517a4e4926bc67d537327d897ec64a76016481b64fe9dbeecd3f53341a7
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: requests-toolbelt, bs4, cloudscraper, scrapethat
# Successfully installed bs4-0.0.1 cloudscraper-1.2.71 requests-toolbelt-1.0.0 scrapethat-1.0.3

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import cloudscraper

def read_html(link):
    response = requests.get(link)
    return(BeautifulSoup(response.text, 'html'))

def read_cloud(link):
    scraper = cloudscraper.create_scraper()  # returns a CloudScraper instance
    response = scraper.get(link)
    return(BeautifulSoup(response.text, 'html'))

def get_texts(link_nodes):
    return([x.text for x in link_nodes])

def strip_text(my_texts):
    return([x.strip() for x in my_texts])

def get_link(link_nodes):
    return([x['href'] for x in link_nodes])

def paste0(base_link, numbers):
    return([f'{base_link}{s}' for s in numbers])

# %% [markdown]
# # Map your function to a list

# %%
def my_func(x):
    return((x**3)+1)

# map(your_function, your_list)
list(map(my_func, range(10)))

# %%
# Find
# soup.find() # return one elemenent
# soup.find_all() # return list of elemenents

# id
soup.find(id='main-heading')
soup.select_one('#main-heading')

# class
soup.find(class_='intro')
soup.select('.intro')

# tag
soup.find('p')


# same as select
soup.select() # return list of elemenents
soup.select_one() # return one elemenent

# Select with select and select_one
# id
soup.select_one('#main-heading')
# class
soup.select('.intro')
# tag
soup.select('p')

# %%
#https://www.boat24.com/en/secondhandboats/
#https://www.geekwire.com/geeklife/
#https://www.imdb.com/title/tt4154796/

# %%
t = read_html('https://www.boat24.com/en/secondhandboats/')
links = [x.find('a')['href'] for x in t.select('.blurb__title') ]

# %%
# Out:
# 'https://www.boat24.com/en/sailingboats/pogo/pogo-40/detail/559937/'

# %%
link = links[0]
print(link)
# Out:
# https://www.boat24.com/en/sailingboats/bavaria/bavaria-37/detail/563901/
